# %%
import random 
name_surname = ["pınarözkan"]
name = input("Name and Surname : ")
grades = {}
selected_courses = []
course_list = ["1:C", "2:C++", "3:C#", "4:PHP", "5:PYTHON"]
tries = 3
if name in name_surname:
    print("Welcome " + name)
elif name not in name_surname and tries > 0:    
    print("Please try again later")
else:
    print("Your information is invalid! Please try again..")
    tries -= 1

print(course_list)
print("You can take a minimum of 3 to and a maximum of 5 lessons.")
for i in range(len(course_list)):
    print(f"{i+1}. {course_list[i]}")
course_num = int(input("How many courses will you take?"))
if course_num < 3 or course_num > 5:
    print("You failed in class!")
else:
    for i in range(course_num):
        selected = int(input(f"Write your {i+1}. course number : "))
        if selected == 1:
            selected_courses.append(course_list[0])
            print("{} dersi listenize eklendi!".format(course_list[0]))
        elif (selected == 2):
            selected_courses.append(course_list[1])
            print("{} dersi listenize eklendi!".format(course_list[1]))
        elif (selected == 3):
            selected_courses.append(course_list[2])
            print("{} dersi listenize eklendi!".format(course_list[2]))
        elif (selected == 4):
            selected_courses.append(course_list[3])
            print("{} dersi listenize eklendi!".format(course_list[3]))
            continue
        else:
            selected_courses.append(course_list[4])
            print("{} dersi listenize eklendi!".format(course_list[4]))  
        selected_courses.append(course_list)   
    print(selected_courses)


selected_course = int(input("Enter a course number for exam : "))
print("{} ".format(selected_courses[selected_course]))

midterm_exam = int(input("Midterm Exam : "))
final = int(input("Final : "))
project = int(input("Project : "))
grades["midterm:"] = midterm_exam
grades["final:"] = final
grades["project:"] = project
print(grades)


calculate = midterm_exam*0.3 + final*0.5 + project*0.2
if calculate > 89:
    print("Your passed with AA.")
elif 90 >calculate > 69:
    print("Your passed with BB.")
elif 70 > calculate > 49:
    print("You passed with CC.")
elif 50 > calculate > 29:
    print("You passed with DD.")
else:
    print("You failed class.")
# Out:
# Name and Surname : pınarözkan
# Welcome pınarözkan
# ['1:C', '2:C++', '3:C#', '4:PHP', '5:PYTHON']
# You can take a minimum of 3 to and a maximum of 5 lessons.
# 1. 1:C
# 2. 2:C++
# 3. 3:C#
# 4. 4:PHP
# 5. 5:PYTHON
# How many courses will you take?4
# Write your 1. course number : 1
# 1:C dersi listenize eklendi!
# Write your 2. course number : 2
# 2:C++ dersi listenize eklendi!
# Write your 3. course number : 3
# 3:C# dersi listenize eklendi!
# Write your 4. course number : 4
# 4:PHP dersi listenize eklendi!
# ['1:C', ['1:C', '2:C++', '3:C#', '4:PHP', '5:PYTHON'], '2:C++', ['1:C', '2:C++', '3:C#', '4:PHP', '5:PYTHON'], '3:C#', ['1:C', '2:C++', '3:C#', '4:PHP', '5:PYTHON'], '4:PHP']
# Enter a course number for exam : 2
# 2:C++
# Midterm Exam : 90
# Final : 80
# Project : 70
# {'midterm:': 90, 'final:': 80, 'project:': 70}
# Your passed with BB.
